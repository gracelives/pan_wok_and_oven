# %% [markdown]
# Course Overview
#
# Module - Welcome Survey: gauge student interest, their goals, and their background
#
# Video - syllabus: Capstone/course overview, syllabus/learning objectives, prerequisites and Grading policy
#
# Video - what is data science?(motivation behind the course, show data with missing values)
#
# Video - leveraging data: the power of data insight and prediction, fueled by examples. Go in to how the data/project helped us make inferences/conclusions
#
# Video - the data science life cycle

# %% [markdown]
# ## New markdown cell
