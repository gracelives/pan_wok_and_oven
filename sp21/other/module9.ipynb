# %% [markdown]
# ## Research methods and HCE
#
# * connection to the data science life cycle, research Q to EDA, then EDA back to refining research Q.
#
# * go over example of good data analysis/research reports
#
# * what questions can be answered by regression: correlation? causation? prediction?
#
# * list of good research practices.
